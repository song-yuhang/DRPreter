# %%
# %load_ext autoreload
# %autoreload 2
import time, os, torch, torchvision, random, time, math
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
if torch.cuda.is_available:
    print('Good to go!')
# Out:
# Good to go!

# %%
arr = np.load("./Data/Cell/cell_feature_std_disjoint.npy", allow_pickle=True)
print(arr)
# Out:
# {'ACH-000001': Data(x=[4646, 1], x_mask=[4646]), 'ACH-000002': Data(x=[4646, 1], x_mask=[4646]), 'ACH-000006': Data(x=[4646, 1], x_mask=[4646]), 'ACH-000007': Data(x=[4646, 1], x_mask=[4646]), 'ACH-000008': Data(x=[4646, 1], x_mask=[4646]), 'ACH-000009': Data(x=[4646, 1], x_mask=[4646]), 'ACH-000012': Data(x=[4646, 1], x_mask=[4646]), 'ACH-000015': Data(x=[4646, 1], x_mask=[4646]), 'ACH-000019': Data(x=[4646, 1], x_mask=[4646]), 'ACH-000020': Data(x=[4646, 1], x_mask=[4646]), 'ACH-000021': Data(x=[4646, 1], x_mask=[4646]), 'ACH-000023': Data(x=[4646, 1], x_mask=[4646]), 'ACH-000024': Data(x=[4646, 1], x_mask=[4646]), 'ACH-000030': Data(x=[4646, 1], x_mask=[4646]), 'ACH-000035': Data(x=[4646, 1], x_mask=[4646]), 'ACH-000040': Data(x=[4646, 1], x_mask=[4646]), 'ACH-000042': Data(x=[4646, 1], x_mask=[4646]), 'ACH-000045': Data(x=[4646, 1], x_mask=[4646]), 'ACH-000046': Data(x=[4646, 1], x_mask=[4646]), 'ACH-000048': Data(x=[4646, 1], x_mask=[4646]), 'ACH-000050': Data(x=[4646, 1], x_mas
# ...

# %%
# 读取.npy文件
cell_dict = np.load("./Data/Cell/cell_feature_std_disjoint.npy", allow_pickle=True).item()  # 使用 pickle 反序列化
print(cell_dict)
cell_dict['ACH-000001'].x.shape[0]
# Out:
# {'ACH-000001': Data(x=[4646, 1], x_mask=[4646]), 'ACH-000002': Data(x=[4646, 1], x_mask=[4646]), 'ACH-000006': Data(x=[4646, 1], x_mask=[4646]), 'ACH-000007': Data(x=[4646, 1], x_mask=[4646]), 'ACH-000008': Data(x=[4646, 1], x_mask=[4646]), 'ACH-000009': Data(x=[4646, 1], x_mask=[4646]), 'ACH-000012': Data(x=[4646, 1], x_mask=[4646]), 'ACH-000015': Data(x=[4646, 1], x_mask=[4646]), 'ACH-000019': Data(x=[4646, 1], x_mask=[4646]), 'ACH-000020': Data(x=[4646, 1], x_mask=[4646]), 'ACH-000021': Data(x=[4646, 1], x_mask=[4646]), 'ACH-000023': Data(x=[4646, 1], x_mask=[4646]), 'ACH-000024': Data(x=[4646, 1], x_mask=[4646]), 'ACH-000030': Data(x=[4646, 1], x_mask=[4646]), 'ACH-000035': Data(x=[4646, 1], x_mask=[4646]), 'ACH-000040': Data(x=[4646, 1], x_mask=[4646]), 'ACH-000042': Data(x=[4646, 1], x_mask=[4646]), 'ACH-000045': Data(x=[4646, 1], x_mask=[4646]), 'ACH-000046': Data(x=[4646, 1], x_mask=[4646]), 'ACH-000048': Data(x=[4646, 1], x_mask=[4646]), 'ACH-000050': Data(x=[4646, 1], x_mas
# ...
